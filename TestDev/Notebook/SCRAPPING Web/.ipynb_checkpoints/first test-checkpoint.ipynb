# %%
# !pip install BeautifulSoup4 
# !pip install tabula-py
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: BeautifulSoup4 in /home/eguimard/.local/lib/python3.10/site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in /home/eguimard/.local/lib/python3.10/site-packages (from BeautifulSoup4) (2.3.2.post1)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tabula-py
#   Downloading tabula_py-2.5.1-py3-none-any.whl (12.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 10.8 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: numpy in /home/eguimard/.local/lib/python3.10/site-packages (from tabula-py) (1.22.3)
# Requirement already satisfied: distro in /usr/lib/python3/dist-packages (from tabula-py) (1.7.0)
# Requirement already satisfied: pandas>=0.25.3 in /home/eguimard/.local/lib/python3.10/site-packages (from tabula-py) (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=0.25.3->tabula-py) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/eguimard/.local/lib/python3.10/site-packages (from pandas>=0.25.3->tabula-py) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.1->pandas>=0.25.3->tabula-py) (1.16.0)
# Installing collected packages: tabula-py
# Successfully installed tabula-py-2.5.1

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.fiakarting.com/event/2022-le-mans/KZ2/results'

# %%
html_response = requests.get(url)
soup = BeautifulSoup(html_response.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    FIA Karting
#   </title>
#   <base href="/"/>
#   <script src="https://www.apex-timing.com/live-timing/tools/ax.iframe.js" type="text/javascript">
#   </script>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="The official website of the FÃ©dÃ©ration Internationale de l'Automobile - Karting" name="description"/>
#   <meta content="index, follow" name="robots"/>
#   <meta content="FIA Karting" name="author"/>
#   <link href="https://use.typekit.net/kns6epx.css" rel="stylesheet"/>
#   <link href="https://openlayers.org/en/v4.6.5/css/ol.css" rel="stylesheet" type="text/css"/>
#   <link href="favicon.ico" rel="icon" type="image/x-icon"/>
#   <link href="styles.c8443068eb8b94ddff6f.css" rel="stylesheet"/>
#  </head>
#  <body>
#   <app-root>
#   </app-root>
#   <script>
#    (function(i, s, o, g, r, a, m) {
#               i['GoogleAnalyticsObject'] = r;
#               i[r] = i[r] || function() {
#                   (i[r].q = i[r].q || []).push(arguments)
#               }, i[r].l = 1 * new Date();
#               a = s.createElement(o),
#                   m = s.getElementsByTagName(o)[0];
#               a.async = 1;
#               a.src = g;
#               m.parentNode.insertBefore(a, m)
#           })(window, document, 'script', 'https://www.google-analytics.com/analytics.js', 'ga');
#   </script>
#   <script src="runtime.784b72b6baadb4f13c37.js">
#   </script>
#   <script nomodule="" src="polyfills-es5.6942cb87e441419f8243.js">
#   </script>
#   <script src="polyfills.75cae90b3f30e9e4907a.js">
#   </script>
#   <script src="main.1d3356aaca74069be3b5.js">
#   </script>
#  </body>
# </html>

# %%
import tabula
import pandas as pd

# %%
pdf_path = '/home/eguimard/Downloads/kz2_results69.pdf'

# %%
# Read pdf into list of DataFrame
dfs = tabula.read_pdf(pdf_path, pages='all')

# %%
l= []
for i in dfs:
    l.append(pd.DataFrame(i))

# %%
len(l)
# Out:
# 23

# %%
l[22]
# Out:
#                                            Unnamed: 0  \
# 0                                                 KZ2
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                              Start : 04/09 - 16:10
# 22                                      Le Mans (FRA)
# 23                                                NaN
# 24                              Timing by Apex Timing
# 25  Apex Timing - drive your success https://www.a...
#
#                                                 Final  Unnamed: 1  Unnamed: 2  \
# 0                                                 NaN         NaN         NaN
# 1                                       Starting Grid         NaN         NaN
# 2   148 Birel Art / Vortex / LeCont Schmitz, Alexa...         NaN         NaN
# 3                222 KR / IAME / LeCont Macia, Daniel         NaN         NaN
# 4   172 Birel Art / TM Racing / LeCont Leuillet, G...         NaN         NaN
# 5       179 Sodi / TM Racing / LeCont Lehouck, Arthur         NaN         NaN
# 6   165 DR / Modena Engines / LeCont Paul, Maximilian         NaN         NaN
# 7      136 Parolin / TM Racing / LeCont Tormen, Marco         NaN         NaN
# 8         124 Sodi / TM Racing / LeCont Gerhards, Tim         NaN         NaN
# 9   120 Birel Art / TM Racing / LeCont Civico Espo...         NaN         NaN
# 10        103 Tony Kart / Vortex / LeCont Luyet, Jean         NaN         NaN
# 11  156 IPK / TM Racing / LeCont Martinez Escrihue...         NaN         NaN
# 12   109 Tony Kart / TM Racing / LeCont Kajak, Markus         NaN         NaN
# 13   101 Birel Art / TM Racing / LeCont Leuillet, Tom         NaN         NaN
# 14      138 Sodi / TM Racing / LeCont Spirgel, Matteo         NaN         NaN
# 15  118 Birel Art / TM Racing / LeCont Kindervater...         NaN         NaN
# 16   161 Maranello / TM Racing / LeCont Arnold, Felix         NaN         NaN
# 17        112 KR / TM Racing / LeCont Lindblad, Arvid         NaN         NaN
# 18  105 Birel Art / TM Racing / LeCont Bertuca, Cr...         NaN         NaN
# 19      130 Tony Kart / Vortex / LeCont Luyet, Samuel         NaN         NaN
# 20                                                NaN         NaN         NaN
# 21                                22 Laps = 30.448 km         NaN         NaN
# 22                                      01-04/09/2022         NaN         NaN
# 23                                                NaN         NaN         NaN
# 24                                                NaN         NaN         NaN
# 25                                                NaN         NaN         NaN
#
#     Unnamed: 3  Unnamed: 4                                         Unnamed: 5  \
# 0          NaN         NaN                                                NaN
# 1          NaN         NaN                                                NaN
# 2        18133         NaN             Nomblot, JeanSodi / TM Racing / LeCont
# 3        17121         NaN       Targett, OscarBirel Art / TM Racing / LeCont
# 4        16220         NaN          Wanegue, VincentSodi / TM Racing / LeCont
# 5        15137         NaN  Marseglia, LeonardoBirel Art / TM Racing / LeCont
# 6        14104         NaN     Piccini, AlessioBirel Art / TM Racing / LeCont
# 7        13107         NaN           Imbourg, ThomasSodi / TM Racing / LeCont
# 8        12153         NaN        Rousseau, CorentinSodi / TM Racing / LeCont
# 9        11169         NaN       Zanchi, MatteoBirel Art / TM Racing / LeCont
# 10       10119         NaN    Paparo, Michael BarbaroIPK / TM Racing / LeCont
# 11        9152         NaN        Leedmaa, SiimTony Kart / TM Racing / LeCont
# 12        8134         NaN               Dale, AndreaCRG / TM Racing / LeCont
# 13        7114         NaN         Vasile, DanielDR / Modena Engines / LeCont
# 14        6102         NaN      Trefilov, DavidMaranello / TM Racing / LeCont
# 15        5122         NaN      Andreasson, NortonTony Kart / Vortex / LeCont
# 16        4129         NaN   Fritsch, ValentinoBirel Art / TM Racing / LeCont
# 17        3117         NaN                 Albanese, DaniloKR / IAME / LeCont
# 18        2108         NaN            Pescador, JorgeCRG / TM Racing / LeCont
# 19        1106         NaN          Carbonnel, ArthurCRG / TM Racing / LeCont
# 20         NaN         NaN                                                NaN
# 21         NaN         NaN                                                NaN
# 22         NaN         NaN                                                NaN
# 23  Page 1 / 1         NaN                                                NaN
# 24         NaN         NaN                                                NaN
# 25         NaN         NaN                                                NaN
#
#     Unnamed: 6                                        Document 83
# 0          NaN                                                NaN
# 1          NaN  Subject to scrutineering & sporting investigat...
# 2          NaN                                                NaN
# 3          NaN                                                NaN
# 4          NaN                                                NaN
# 5          NaN                                                NaN
# 6          NaN                                                NaN
# 7          NaN                                                NaN
# 8          NaN                                                NaN
# 9          NaN                                                NaN
# 10         NaN                                                NaN
# 11         NaN                                                NaN
# 12         NaN                                                NaN
# 13         NaN                                                NaN
# 14         NaN                                                NaN
# 15         NaN                                                NaN
# 16         NaN                                                NaN
# 17         NaN                                                NaN
# 18         NaN                                                NaN
# 19         NaN                                                NaN
# 20         NaN                                      POLE POSITION
# 21         NaN                                                NaN
# 22         NaN                                                NaN
# 23         NaN                                                NaN
# 24         NaN                               Apex Timing GoRacing
# 25         NaN                                                NaN

# %%
# Read remote pdf into list of DataFrame
dfs2 = tabula.read_pdf("https://github.com/tabulapdf/tabula-java/raw/master/src/test/resources/technology/tabula/arabic.pdf")

# convert PDF into CSV file
tabula.convert_into("test.pdf", "output.csv", output_format="csv", pages='all')

# convert all PDFs in a directory
tabula.convert_into_by_batch("input_directory", output_format='csv', pages='all')
